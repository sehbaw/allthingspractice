# %% [markdown]
# <a href="https://colab.research.google.com/github/sehbaw/allthingspractice/blob/main/cleanmachine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("/bmore.csv")

# %%
df.head()

df.dropna()
# Out:
#                                          organization  \
# 0          Modell Performing Arts Center at the Lyric
# 1   National James Baldwin Literary Society, Inc./BMI
# 2                              Vagabond Players, Inc.
# 3                             Baltimore Jazz Alliance
# 4                                     CityLit Project
# ..                                                ...
# 75                                  Creative Alliance
# 76                                          ARTblocks
# 77                                         Hippodrome
# 78         Station North Art & Entertainment District
# 79                             MD Humanities Council
#
#                                adress      cityState  zipCode  \
# 0                140 West Mount Royal  Baltimore, MD    21201
# 1              3618 Greenmount Avenue  Baltimore, MD    21218
# 2                     806 S. Broadway  Baltimore, MD    21231
# 3                847 N. Howard Street  Baltimore, MD    21201
# ...

# %% [markdown]
# I want to split the last column

# %%
df[['lat', 'lon']] = df['Location 1'].str.split(' ', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-54a509aecf30> in <cell line: 1>()
# ----> 1 df[['lat', 'lon']] = df['Location 1'].str.split(' ', expand=True)
#       2
#       3
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
#    3940             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3978
#    3979             if isinstance(value, DataFrame):
# -> 3980                 check_key_length(self.columns, key, value)
#    3981                 for k1, k2 in zip(key, value.columns):
# ...

# %%
df[['address', 'zip', 'lat', 'lon']] = df['Location 1'].str.extract(r'(.+?)\s(\d{5})\s\(([^,]+),\s([^)]+)\)', expand=True)
df

df[["city", "state"]] = df["cityState"].str.split(' ', expand=True)
df

df["city"].replace(",", " ")
df
# Out:
#                                          organization  \
# 0          Modell Performing Arts Center at the Lyric
# 1   National James Baldwin Literary Society, Inc./BMI
# 2                              Vagabond Players, Inc.
# 3                             Baltimore Jazz Alliance
# 4                                     CityLit Project
# ..                                                ...
# 75                                  Creative Alliance
# 76                                          ARTblocks
# 77                                         Hippodrome
# 78         Station North Art & Entertainment District
# 79                             MD Humanities Council
#
#                                adress      cityState  zipCode  \
# 0                140 West Mount Royal  Baltimore, MD    21201
# 1              3618 Greenmount Avenue  Baltimore, MD    21218
# 2                     806 S. Broadway  Baltimore, MD    21231
# 3                847 N. Howard Street  Baltimore, MD    21201
# ...

# %%
df.drop(columns=["Location 1", "adress", "cityState", "zipCode"])
# Out:
#                                          organization  \
# 0          Modell Performing Arts Center at the Lyric
# 1   National James Baldwin Literary Society, Inc./BMI
# 2                              Vagabond Players, Inc.
# 3                             Baltimore Jazz Alliance
# 4                                     CityLit Project
# ..                                                ...
# 75                                  Creative Alliance
# 76                                          ARTblocks
# 77                                         Hippodrome
# 78         Station North Art & Entertainment District
# 79                             MD Humanities Council
#
#                                            URL  \
# 0              http://www.lyricoperahouse.com/
# 1       http://jamesbaldwin.org/Home_Page.html
# 2              http://www.vagabondplayers.org/
# 3                http://www.baltimorejazz.com/
# 4               http://www.citylitproject.org/
# ...
